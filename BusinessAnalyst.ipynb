# %%
import pandas as pd

df = pd.read_csv("customers-100.csv")
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
pivot = df.pivot_table(index='Country', values='Customer Id', aggfunc='count')
pivot = pivot.reset_index()
pivot.columns = ['Country', 'CustomerCount']  # Rename columns for clarity
pivot.head()
# Out:
#                Country  CustomerCount
# 0              Albania              1
# 1              Algeria              1
# 2             Anguilla              1
# 3  Antigua and Barbuda              1
# 4                Aruba              1

# %%
import plotly.express as px

fig = px.bar(pivot, x='Country', y=pivot.columns[1], title="Customers by Country")
fig.show()

# %%
print(df.columns)
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %% [markdown]
# ## Sample Dashboard Layout
#
# - Pivot Table: Customer Count by Country
# - Plotly Bar Chart: Interactive view of customers
# - Filters (optional): By Region, Age Group, or Spending
# - Future Add-ons: Map visual, Trend line, Customer segment breakdown
